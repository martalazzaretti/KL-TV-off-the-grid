        [ -845.0000,  1235.0000,   625.0000],
        [ -780.0000,  1560.0000, -1375.0000],
        [-2080.0000,  2015.0000, -1875.0000],
        [ 1040.0000, -2015.0000,  -375.0000],
        [-3055.0000,  1170.0000,  -875.0000],
        [ -390.0000,  1430.0000, -1875.0000],
        [ 1495.0000,  -650.0000,  -125.0000],
        [-1755.0000,  1690.0000, -1375.0000],
        [  520.0000,   -65.0000,  -875.0000],
        [ 2275.0000, -1430.0000, -1375.0000],
        [  975.0000,   650.0000, -1375.0000]];

# %%
N_xy = 190 #grid x-y plane
N_z = 17 #z slices
pixel_size_xy = 65
pixel_size_z = 250
sizeGrid_xy = N_xy * pixel_size_xy
sizeGrid_z = N_z * pixel_size_z

# %%
a = a_k/np.max(a_k)
N = np.size(a)

x=np.empty(N)
y=np.empty(N)
z=np.empty(N)
for i in range(N):
    x[i] = x_k[i][0]
    y[i] = x_k[i][1]
    z[i] = x_k[i][2]

# %%
# Define colormap based on depth (z-coordinate)
colors = (z - z.min()) / (z.max() - z.min())  # Normalize depth values and map to colors

# Plot the 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='jet', marker='o', s=5, alpha=0.7)

# Customize plot
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_ylim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_zlim(-sizeGrid_z/2, sizeGrid_z/2)


# Create colorbar with matching colors
cbar = plt.colorbar(sc, shrink=0.5)
cbar.set_ticks([0, 0.5, 1])  # Set custom tick locations
cbar.set_ticklabels([np.round(z.min(),1), np.round((z.max() - z.min()) / 2 + z.min(),1), np.round(z.max(),1)])  # Set custom tick labels


ax.view_init(0, 60)

plt.show()

# %%
# Define colormap based on depth (z-coordinate)
colors = (z - z.min()) / (z.max() - z.min())  # Normalize depth values and map to colors

# Plot the 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='jet', marker='o', s=5, alpha=0.7)

# Customize plot
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_ylim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_zlim(-sizeGrid_z/2, sizeGrid_z/2)


# Create colorbar with matching colors
cbar = plt.colorbar(sc, shrink=0.75)
cbar.set_ticks([0, 0.5, 1])  # Set custom tick locations
cbar.set_ticklabels([np.round(z.min(),1), np.round((z.max() - z.min()) / 2 + z.min(),1), np.round(z.max(),1)])  # Set custom tick labels


ax.view_init(90, 60)

plt.show()

# %%
# Define colormap based on depth (z-coordinate)
colors = (z - z.min()) / (z.max() - z.min())  # Normalize depth values and map to colors

# Plot the 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(x, y, z, c=colors, cmap='jet', marker='o', s=5, alpha=0.7)

# Customize plot
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_ylim(-sizeGrid_xy/2, sizeGrid_xy/2)
ax.set_zlim(-sizeGrid_z/2, sizeGrid_z/2)


# Create colorbar with matching colors
cbar = plt.colorbar(sc, shrink=0.5)
cbar.set_ticks([0, 0.5, 1])  # Set custom tick locations
cbar.set_ticklabels([np.round(z.min(),1), np.round((z.max() - z.min()) / 2 + z.min(),1), np.round(z.max(),1)])  # Set custom tick labels


# ax.view_init(0, 60)

plt.show()
